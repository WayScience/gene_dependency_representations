# %% [markdown]
# ## Describe PRISM data

# %%
import pathlib
import sys

import pandas as pd

sys.path.append("../")
from utils import load_utils

# %%
# Load PRISM data
top_dir = "../5.drug-dependency"
data_dir = "data"

prism_df, prism_cell_df, prism_trt_df = load_utils.load_prism(
    top_dir=top_dir,
    data_dir=data_dir,
    secondary_screen=False,
    load_cell_info=True,
    load_treatment_info=True,
)

print(prism_df.shape)
prism_df.head(3)
# Out:
# (578, 4686)
#             BRD-A00077618-236-07-6::2.5::HTS  \
# ACH-000001                         -0.015577
# ACH-000007                         -0.095730
# ACH-000008                          0.379480
#
#             BRD-A00100033-001-08-9::2.5::HTS  \
# ACH-000001                         -0.449332
# ACH-000007                          0.257943
# ACH-000008                         -0.596132
#
#             BRD-A00147595-001-01-5::2.5::HTS  \
# ACH-000001                          0.489379
# ACH-000007                          0.772349
# ACH-000008                          0.548056
#
#             BRD-A00218260-001-03-4::2.5::HTS  \
# ACH-000001                          0.206675
# ACH-000007                         -0.438502
# ACH-000008                          0.422269
#
#             BRD-A00376169-001-01-6::2.5::HTS  \
# ACH-000001                          0.272730
# ACH-000007                         -0.732832
# ACH-000008                         -0.216986
#
#             BRD-A00520476-001-07-4::2.5::HTS  \
# ACH-000001                          0.021036
# ACH-000007                          0.779201
# ACH-000008                          0.081866
#
#             BRD-A00546892-001-02-6::2.5::HTS  \
# ACH-000001                         -0.025460
# ACH-000007                          0.426523
# ACH-000008                          0.145335
#
#             BRD-A00578795-001-04-3::2.5::HTS  \
# ACH-000001                          0.467158
# ACH-000007                         -1.288508
# ACH-000008                         -0.570841
#
#             BRD-A00758722-001-04-9::2.5::HTS  \
# ACH-000001                         -0.736306
# ACH-000007                         -0.476133
# ACH-000008                         -0.512119
#
#             BRD-A00827783-001-24-6::2.5::HTS  ...  \
# ACH-000001                          0.644137  ...
# ACH-000007                         -0.277105  ...
# ACH-000008                          0.452698  ...
#
#             BRD-K98557884-001-01-6::2.5::MTS004  \
# ACH-000001                             0.429238
# ACH-000007                            -0.471486
# ACH-000008                            -0.111951
#
#             BRD-K99077012-001-01-9::2.332734192::MTS004  \
# ACH-000001                                     0.204841
# ACH-000007                                     0.212998
# ACH-000008                                     0.534787
#
#             BRD-K99199077-001-16-1::2.603211317::MTS004  \
# ACH-000001                                     0.150055
# ACH-000007                                    -0.123230
# ACH-000008                                     0.206642
#
#             BRD-K99431849-001-01-7::2.500018158::MTS004  \
# ACH-000001                                    -0.575404
# ACH-000007                                     0.625527
# ACH-000008                                    -0.410153
#
#             BRD-K99447003-335-04-1::2.37737659::MTS004  \
# ACH-000001                                   -0.101247
# ACH-000007                                    0.383198
# ACH-000008                                   -0.560722
#
#             BRD-K99506538-001-03-8::2.5::MTS004  \
# ACH-000001                             0.399233
# ACH-000007                             0.212031
# ACH-000008                            -0.036088
#
#             BRD-K99616396-001-05-1::2.499991421::MTS004  \
# ACH-000001                                    -0.127658
# ACH-000007                                     0.349225
# ACH-000008                                     0.158071
#
#             BRD-K99879819-001-02-1::2.5187366::MTS004  \
# ACH-000001                                  -0.141651
# ACH-000007                                  -0.387439
# ACH-000008                                   0.171043
#
#             BRD-K99919177-001-01-3::2.5::MTS004  \
# ACH-000001                            -1.153652
# ACH-000007                            -0.831461
# ACH-000008                            -3.947090
#
#             BRD-M63173034-001-03-6::2.64076472::MTS004
# ACH-000001                                    0.510464
# ACH-000007                                    0.323558
# ACH-000008                                    0.099310
#
# [3 rows x 4686 columns]

# %%
print(prism_cell_df.shape)
prism_cell_df.head(3)
# Out:
# (588, 12)
#      row_name   depmap_id           ccle_name primary_tissue  \
# 0  ACH-000824  ACH-000824  KYSE510_OESOPHAGUS      esophagus
# 1  ACH-000954  ACH-000954   HEC1A_ENDOMETRIUM         uterus
# 2  ACH-000601  ACH-000601   MIAPACA2_PANCREAS       pancreas
#
#      secondary_tissue tertiary_tissue  passed_str_profiling  \
# 0  esophagus_squamous             NaN                  True
# 1  uterus_endometrium             NaN                  True
# 2                 NaN             NaN                  True
#
#   str_profiling_notes originally_assigned_depmap_id  \
# 0                 NaN                           NaN
# 1                 NaN                           NaN
# 2                 NaN                           NaN
#
#   originally_assigned_ccle_name cell_line_clean       tissue
# 0                           NaN         KYSE510   OESOPHAGUS
# 1                           NaN           HEC1A  ENDOMETRIUM
# 2                           NaN        MIAPACA2     PANCREAS

# %%
print(prism_trt_df.shape)
prism_trt_df.head(3)
# Out:
# (4686, 11)
#                                    column_name                broad_id  \
# 0  BRD-A00055058-001-01-0::2.325889319::MTS004  BRD-A00055058-001-01-0
# 1          BRD-A00842753-001-01-9::2.5::MTS004  BRD-A00842753-001-01-9
# 2          BRD-A02232681-001-01-8::2.5::MTS004  BRD-A02232681-001-01-8
#
#          name      dose screen_id                        moa  \
# 0     RS-0481  2.325889    MTS004            immunostimulant
# 1  oleuropein  2.500000    MTS004  estrogen receptor agonist
# 2  isoleucine  2.500000    MTS004                        NaN
#
#                               target disease.area indication  \
# 0                                NaN          NaN        NaN
# 1                              GPER1          NaN        NaN
# 2  ACADSB, BCAT1, BCAT2, IARS, IARS2          NaN        NaN
#
#                                               smiles     phase
# 0             CC(NC(=O)C1CSCN1C(=O)c1ccccc1)c1ccccc1   Phase 2
# 1  COC(=O)C1=COC(OC2OC(CO)C(O)C(O)C2O)\C(=C/C)C1C...   Phase 2
# 2                                   CCC(C)C(N)C(O)=O  Launched

# %%
# How many tissues
prism_cell_df.loc[:, "tissue"].value_counts()
# Out:
# tissue
# LUNG                         101
# SKIN                          43
# CENTRAL_NERVOUS_SYSTEM        42
# OVARY                         38
# PANCREAS                      37
# LARGE_INTESTINE               35
# BREAST                        26
# UPPER_AERODIGESTIVE_TRACT     25
# OESOPHAGUS                    24
# URINARY_TRACT                 24
# SOFT_TISSUE                   22
# ENDOMETRIUM                   22
# STOMACH                       21
# LIVER                         21
# BONE                          19
# KIDNEY                        19
# AUTONOMIC_GANGLIA             12
# THYROID                       11
# FAILED_STR                    10
# CONTROL                       10
# PLEURA                         9
# BILIARY_TRACT                  7
# PROSTATE                       4
# ENGINEERED                     4
# SALIVARY_GLAND                 2
# Name: count, dtype: int64

# %%
# How many unique treatments
print(prism_trt_df.name.nunique())

# How many MOAs
print(prism_trt_df.moa.nunique())
prism_trt_df.moa.value_counts().head(20)
# Out:
# 4517
# 1072
# moa
# cyclooxygenase inhibitor                   89
# adrenergic receptor antagonist             89
# adrenergic receptor agonist                81
# acetylcholine receptor antagonist          78
# histamine receptor antagonist              68
# dopamine receptor antagonist               62
# bacterial cell wall synthesis inhibitor    61
# glutamate receptor antagonist              61
# serotonin receptor antagonist              60
# phosphodiesterase inhibitor                56
# glucocorticoid receptor agonist            51
# serotonin receptor agonist                 50
# calcium channel blocker                    44
# acetylcholine receptor agonist             40
# bacterial DNA gyrase inhibitor             37
# sodium channel blocker                     36
# topoisomerase inhibitor                    35
# EGFR inhibitor                             34
# dopamine receptor agonist                  33
# PI3K inhibitor                             33
# Name: count, dtype: int64

# %% [markdown]
# ## Secondary screen data

# %%
prism_df, prism_cell_df, prism_trt_df = load_utils.load_prism(
    top_dir=top_dir,
    data_dir=data_dir,
    secondary_screen=True,
    load_cell_info=True,
    load_treatment_info=True,
)

print(prism_df.shape)
prism_df.head(3)
# Out:
# (489, 13008)
#                        BRD-A00077618-236-07-6::0.00061034::HTS002  \
# ACH-000007                                               0.155931
# ACH-000008                                               0.184596
# ACH-000010_FAILED_STR                                   -0.039424
#
#                        BRD-A00077618-236-07-6::0.0024414::HTS002  \
# ACH-000007                                              0.019271
# ACH-000008                                              0.225428
# ACH-000010_FAILED_STR                                   0.541074
#
#                        BRD-A00077618-236-07-6::0.00976562::HTS002  \
# ACH-000007                                              -0.325728
# ACH-000008                                               0.514571
# ACH-000010_FAILED_STR                                    0.291428
#
#                        BRD-A00077618-236-07-6::0.0390625::HTS002  \
# ACH-000007                                              0.162858
# ACH-000008                                              0.053359
# ACH-000010_FAILED_STR                                  -0.308274
#
#                        BRD-A00077618-236-07-6::0.15625::HTS002  \
# ACH-000007                                            0.321621
# ACH-000008                                            0.308493
# ACH-000010_FAILED_STR                                 0.103168
#
#                        BRD-A00077618-236-07-6::0.625::HTS002  \
# ACH-000007                                          0.090677
# ACH-000008                                          0.333541
# ACH-000010_FAILED_STR                               0.089309
#
#                        BRD-A00077618-236-07-6::10::HTS002  \
# ACH-000007                                      -0.673910
# ACH-000008                                      -0.109190
# ACH-000010_FAILED_STR                            0.164341
#
#                        BRD-A00077618-236-07-6::2.5::HTS002  \
# ACH-000007                                        0.488094
# ACH-000008                                        0.509444
# ACH-000010_FAILED_STR                             0.236018
#
#                        BRD-A00758722-001-04-9::0.00061034::HTS002  \
# ACH-000007                                               0.012847
# ACH-000008                                               0.591794
# ACH-000010_FAILED_STR                                         NaN
#
#                        BRD-A00758722-001-04-9::0.0024414::HTS002  ...  \
# ACH-000007                                              0.837298  ...
# ACH-000008                                              0.453814  ...
# ACH-000010_FAILED_STR                                        NaN  ...
#
#                        BRD-U25960968-000-01-9::10::HTS002  \
# ACH-000007                                      -1.211172
# ACH-000008                                       0.002228
# ACH-000010_FAILED_STR                                 NaN
#
#                        BRD-U25960968-000-01-9::2.5::HTS002  \
# ACH-000007                                       -0.030709
# ACH-000008                                        0.764709
# ACH-000010_FAILED_STR                                  NaN
#
#                        BRD-U45393375-000-01-6::0.000610351569230769::HTS002  \
# ACH-000007                                                      0.109745
# ACH-000008                                                      0.195910
# ACH-000010_FAILED_STR                                          -0.445411
#
#                        BRD-U45393375-000-01-6::0.00244140624615385::HTS002  \
# ACH-000007                                                      1.091437
# ACH-000008                                                      0.440849
# ACH-000010_FAILED_STR                                           0.403367
#
#                        BRD-U45393375-000-01-6::0.009765625::HTS002  \
# ACH-000007                                                0.845174
# ACH-000008                                                0.130811
# ACH-000010_FAILED_STR                                    -0.428090
#
#                        BRD-U45393375-000-01-6::0.0390625::HTS002  \
# ACH-000007                                              0.914664
# ACH-000008                                              0.114002
# ACH-000010_FAILED_STR                                  -0.050511
#
#                        BRD-U45393375-000-01-6::0.15625::HTS002  \
# ACH-000007                                            0.308181
# ACH-000008                                            0.227759
# ACH-000010_FAILED_STR                                 1.262123
#
#                        BRD-U45393375-000-01-6::0.625::HTS002  \
# ACH-000007                                          0.487404
# ACH-000008                                          0.230646
# ACH-000010_FAILED_STR                               0.677607
#
#                        BRD-U45393375-000-01-6::10::HTS002  \
# ACH-000007                                       0.100248
# ACH-000008                                      -0.148456
# ACH-000010_FAILED_STR                            0.144283
#
#                        BRD-U45393375-000-01-6::2.5::HTS002
# ACH-000007                                        1.018868
# ACH-000008                                        0.110857
# ACH-000010_FAILED_STR                            -0.090171
#
# [3 rows x 13008 columns]

# %%
print(prism_cell_df.shape)
prism_cell_df.head(3)
# Out:
# (588, 9)
#      row_name   depmap_id           ccle_name primary_tissue  \
# 0  ACH-000824  ACH-000824  KYSE510_OESOPHAGUS      esophagus
# 1  ACH-000954  ACH-000954   HEC1A_ENDOMETRIUM         uterus
# 2  ACH-000601  ACH-000601   MIAPACA2_PANCREAS       pancreas
#
#      secondary_tissue tertiary_tissue passed_str_profiling cell_line_clean  \
# 0  esophagus_squamous             NaN                 True         KYSE510
# 1  uterus_endometrium             NaN                 True           HEC1A
# 2                 NaN             NaN                 True        MIAPACA2
#
#         tissue
# 0   OESOPHAGUS
# 1  ENDOMETRIUM
# 2     PANCREAS

# %%
print(prism_trt_df.shape)
prism_trt_df.head(3)
# Out:
# (13008, 12)
#                                          column_name                broad_id  \
# 0  BRD-A25234499-001-19-1::0.00061::MTS010::PROS0...  BRD-A25234499-001-19-1
# 1  BRD-A25234499-001-19-1::0.00244::MTS010::PROS0...  BRD-A25234499-001-19-1
# 2  BRD-A25234499-001-19-1::0.00977::MTS010::PROS0...  BRD-A25234499-001-19-1
#
#       dose screen_id compound_plate               name  \
# 0  0.00061    MTS010  PROS003_PR500  aminoglutethimide
# 1  0.00244    MTS010  PROS003_PR500  aminoglutethimide
# 2  0.00977    MTS010  PROS003_PR500  aminoglutethimide
#
#                                   moa            target  \
# 0  glucocorticoid receptor antagonist  CYP11A1, CYP19A1
# 1  glucocorticoid receptor antagonist  CYP11A1, CYP19A1
# 2  glucocorticoid receptor antagonist  CYP11A1, CYP19A1
#
#               disease.area                         indication  \
# 0  endocrinology, oncology  Cushing's syndrome, breast cancer
# 1  endocrinology, oncology  Cushing's syndrome, breast cancer
# 2  endocrinology, oncology  Cushing's syndrome, breast cancer
#
#                                               smiles     phase
# 0  CCC1(CCC(=O)NC1=O)c1ccc(N)cc1, CCC1(CCC(=O)NC1...  Launched
# 1  CCC1(CCC(=O)NC1=O)c1ccc(N)cc1, CCC1(CCC(=O)NC1...  Launched
# 2  CCC1(CCC(=O)NC1=O)c1ccc(N)cc1, CCC1(CCC(=O)NC1...  Launched

# %%
# How many tissues in secondary screen
prism_cell_df.loc[:, "tissue"].value_counts()
# Out:
# tissue
# LUNG                         105
# CENTRAL_NERVOUS_SYSTEM        43
# SKIN                          43
# OVARY                         40
# PANCREAS                      37
# LARGE_INTESTINE               35
# BREAST                        27
# UPPER_AERODIGESTIVE_TRACT     25
# OESOPHAGUS                    24
# URINARY_TRACT                 24
# SOFT_TISSUE                   22
# ENDOMETRIUM                   22
# LIVER                         21
# STOMACH                       21
# KIDNEY                        19
# BONE                          19
# AUTONOMIC_GANGLIA             12
# THYROID                       11
# CONTROL                       10
# PLEURA                         9
# BILIARY_TRACT                  7
# PROSTATE                       4
# ENGINEERED                     4
# SALIVARY_GLAND                 2
# FIBROBLAST                     1
# UPPER_AERODIGESTIVE            1
# Name: count, dtype: int64

# %%
# How many unique treatments
print(prism_trt_df.name.nunique())

# How many MOAs
print(prism_trt_df.moa.nunique())
prism_trt_df.moa.value_counts().head(20)
# Out:
# 1448
# 530
# moa
# EGFR inhibitor                      376
# HDAC inhibitor                      240
# topoisomerase inhibitor             192
# glucocorticoid receptor agonist     192
# CDK inhibitor                       192
# tubulin polymerization inhibitor    184
# MEK inhibitor                       184
# mTOR inhibitor                      160
# Aurora kinase inhibitor             152
# histamine receptor antagonist       144
# HSP inhibitor                       144
# PI3K inhibitor                      144
# protein synthesis inhibitor         144
# adrenergic receptor antagonist      136
# RAF inhibitor                       128
# cyclooxygenase inhibitor            120
# glutamate receptor antagonist       112
# PARP inhibitor                      112
# adrenergic receptor agonist         112
# dopamine receptor antagonist        104
# Name: count, dtype: int64

# %%
# How many doses per compound
prism_trt_df.groupby("name").dose.count().value_counts()
# Out:
# dose
# 8     1279
# 16     166
# 48       2
# 24       1
# Name: count, dtype: int64
