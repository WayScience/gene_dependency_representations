# %%
import pandas as pd
from scipy.stats import pearsonr
import pathlib
import sys
import numpy as np

sys.path.append("../")
from utils import load_utils

# %%
# Load PRISM data
top_dir = "../5.drug-dependency"
data_dir = "data"

prism_df, prism_cell_df, prism_trt_df = load_utils.load_prism(
    top_dir=top_dir,
    data_dir=data_dir,
    secondary_screen=False,
    load_cell_info=True,
    load_treatment_info=True,
)

# Reset the index and name it ModelID
prism_df.reset_index(inplace=True)
prism_df.rename(columns={'index': 'ModelID'}, inplace=True)

# Check the result
print(prism_df.shape)
prism_df.head(3)
# Out:
# (578, 4687)
#       ModelID  BRD-A00077618-236-07-6::2.5::HTS  \
# 0  ACH-000001                         -0.015577
# 1  ACH-000007                         -0.095730
# 2  ACH-000008                          0.379480
#
#    BRD-A00100033-001-08-9::2.5::HTS  BRD-A00147595-001-01-5::2.5::HTS  \
# 0                         -0.449332                          0.489379
# 1                          0.257943                          0.772349
# 2                         -0.596132                          0.548056
#
#    BRD-A00218260-001-03-4::2.5::HTS  BRD-A00376169-001-01-6::2.5::HTS  \
# 0                          0.206675                          0.272730
# 1                         -0.438502                         -0.732832
# 2                          0.422269                         -0.216986
#
#    BRD-A00520476-001-07-4::2.5::HTS  BRD-A00546892-001-02-6::2.5::HTS  \
# 0                          0.021036                         -0.025460
# 1                          0.779201                          0.426523
# 2                          0.081866                          0.145335
#
#    BRD-A00578795-001-04-3::2.5::HTS  BRD-A00758722-001-04-9::2.5::HTS  ...  \
# 0                          0.467158                         -0.736306  ...
# 1                         -1.288508                         -0.476133  ...
# 2                         -0.570841                         -0.512119  ...
#
#    BRD-K98557884-001-01-6::2.5::MTS004  \
# 0                             0.429238
# 1                            -0.471486
# 2                            -0.111951
#
#    BRD-K99077012-001-01-9::2.332734192::MTS004  \
# 0                                     0.204841
# 1                                     0.212998
# 2                                     0.534787
#
#    BRD-K99199077-001-16-1::2.603211317::MTS004  \
# 0                                     0.150055
# 1                                    -0.123230
# 2                                     0.206642
#
#    BRD-K99431849-001-01-7::2.500018158::MTS004  \
# 0                                    -0.575404
# 1                                     0.625527
# 2                                    -0.410153
#
#    BRD-K99447003-335-04-1::2.37737659::MTS004  \
# 0                                   -0.101247
# 1                                    0.383198
# 2                                   -0.560722
#
#    BRD-K99506538-001-03-8::2.5::MTS004  \
# 0                             0.399233
# 1                             0.212031
# 2                            -0.036088
#
#    BRD-K99616396-001-05-1::2.499991421::MTS004  \
# 0                                    -0.127658
# 1                                     0.349225
# 2                                     0.158071
#
#    BRD-K99879819-001-02-1::2.5187366::MTS004  \
# 0                                  -0.141651
# 1                                  -0.387439
# 2                                   0.171043
#
#    BRD-K99919177-001-01-3::2.5::MTS004  \
# 0                            -1.153652
# 1                            -0.831461
# 2                            -3.947090
#
#    BRD-M63173034-001-03-6::2.64076472::MTS004
# 0                                    0.510464
# 1                                    0.323558
# 2                                    0.099310
#
# [3 rows x 4687 columns]

# %%
#Load reactome pathways
pathway_dir = pathlib.Path("../3.analysis/results/significant_gsea_results.parquet.gz").resolve()
pathway_df = pd.read_parquet(pathway_dir)
pathway_df.head()
# Out:
#                                                  Term        es       nes  \
# 0                           mRNA Splicing R-HSA-72172 -0.654698 -7.429723
# 1           mRNA Splicing - Major Pathway R-HSA-72163 -0.676886 -7.371983
# 2   Processing Of Capped Intron-Containing Pre-mRN... -0.605070 -7.371129
# 13  APC/C-mediated Degradation Of Cell Cycle Prote... -0.723782 -6.112642
# 14  Antigen Processing: Ubiquitination And Proteas... -0.585487 -6.063218
#
#             pval         sidak           fdr  geneset_size  \
# 0   1.088256e-13  1.129610e-10  5.853937e-11           109
# 1   1.681083e-13  1.744964e-10  5.853937e-11           104
# 2   1.691889e-13  1.756181e-10  5.853937e-11           141
# 13  9.799483e-10  1.017186e-06  7.265617e-08            61
# 14  1.334247e-09  1.384948e-06  9.232992e-08           101
#
#                                          leading_edge z_dim source
# 0   DHX9,DHX38,DHX15,CDC5L,PCF11,PLRG1,LSM7,PRPF6,...   z_1   real
# 1   DHX9,DHX38,DHX15,CDC5L,PCF11,PLRG1,LSM7,PRPF6,...   z_1   real
# 2   DHX9,DHX38,DHX15,CDC5L,PCF11,PLRG1,LSM7,PRPF6,...   z_1   real
# 13  PSMB3,ANAPC4,CDK1,PSMB1,RB1,PSMB5,PSMD11,PSMD1...   z_1   real
# 14  PSMB3,LRR1,PSMD9,ANAPC4,PSMB1,KEAP1,HECTD1,PSM...   z_1   real

# %%
# load the latent dim matrix 
latent_dir = pathlib.Path("../2.train-VAE/results/latent_df.parquet").resolve()
latent_df = pd.read_parquet(latent_dir)
latent_df.head()
# Out:
#       ModelID    0    1         2         3         4    5         6  \
# 0  ACH-000748  0.0  0.0  2.931751  1.300346  0.968795  0.0  0.079798
# 1  ACH-000645  0.0  0.0  1.865084  0.886528  0.897159  0.0  0.156185
# 2  ACH-001301  0.0  0.0  2.396594  1.361056  0.183786  0.0  0.000000
# 3  ACH-000361  0.0  0.0  2.906988  1.973957  0.100008  0.0  0.000000
# 4  ACH-000325  0.0  0.0  3.764669  3.333713  0.000000  0.0  0.000000
#
#           7         8  ...        26   27   28   29   30        31        32  \
# 0  2.580413  0.242330  ...  1.407413  0.0  0.0  0.0  0.0  0.689580  1.444408
# 1  2.279790  0.061815  ...  0.817676  0.0  0.0  0.0  0.0  0.000000  1.385956
# 2  2.563383  0.000000  ...  0.618336  0.0  0.0  0.0  0.0  0.823913  1.231781
# 3  2.699383  0.000000  ...  0.911914  0.0  0.0  0.0  0.0  1.754643  1.337547
# 4  4.411053  0.000000  ...  0.045819  0.0  0.0  0.0  0.0  3.796674  1.755739
#
#          33        34        35
# 0  0.170970  3.589293  1.664138
# 1  0.009952  1.823041  1.082538
# 2  0.000000  2.180012  0.911842
# 3  0.000000  2.751270  1.274395
# 4  0.000000  2.519099  0.682146
#
# [5 rows x 37 columns]

# %%
# Ensure ModelID is the index for both dataframes to align 
latent_df.set_index('ModelID', inplace=True)
prism_df.set_index('ModelID', inplace=True)
latent_df.head()
# Out:
#               0    1         2         3         4    5         6         7  \
# ModelID
# ACH-000748  0.0  0.0  2.931751  1.300346  0.968795  0.0  0.079798  2.580413
# ACH-000645  0.0  0.0  1.865084  0.886528  0.897159  0.0  0.156185  2.279790
# ACH-001301  0.0  0.0  2.396594  1.361056  0.183786  0.0  0.000000  2.563383
# ACH-000361  0.0  0.0  2.906988  1.973957  0.100008  0.0  0.000000  2.699383
# ACH-000325  0.0  0.0  3.764669  3.333713  0.000000  0.0  0.000000  4.411053
#
#                    8         9  ...        26   27   28   29   30        31  \
# ModelID                         ...
# ACH-000748  0.242330  3.798377  ...  1.407413  0.0  0.0  0.0  0.0  0.689580
# ACH-000645  0.061815  3.558936  ...  0.817676  0.0  0.0  0.0  0.0  0.000000
# ACH-001301  0.000000  3.603009  ...  0.618336  0.0  0.0  0.0  0.0  0.823913
# ACH-000361  0.000000  3.965211  ...  0.911914  0.0  0.0  0.0  0.0  1.754643
# ACH-000325  0.000000  6.069576  ...  0.045819  0.0  0.0  0.0  0.0  3.796674
#
#                   32        33        34        35
# ModelID
# ACH-000748  1.444408  0.170970  3.589293  1.664138
# ACH-000645  1.385956  0.009952  1.823041  1.082538
# ACH-001301  1.231781  0.000000  2.180012  0.911842
# ACH-000361  1.337547  0.000000  2.751270  1.274395
# ACH-000325  1.755739  0.000000  2.519099  0.682146
#
# [5 rows x 36 columns]

# %%
# Align both dataframes based on the ModelID
common_model_ids = latent_df.index.intersection(prism_df.index)

# %%
# Filter both dataframes to keep only common ModelIDs
latent_df_filtered = latent_df.loc[common_model_ids]
prism_df_filtered = prism_df.loc[common_model_ids]

# %%
# Check the variance of each latent dimension and drug response column
latent_variance = latent_df_filtered.var()
prism_variance = prism_df_filtered.var()

# Filter out constant columns (variance == 0)
latent_df_filtered = latent_df_filtered.loc[:, latent_variance != 0]
prism_df_filtered = prism_df_filtered.loc[:, prism_variance != 0]

# %%
latent_df_filtered.head()
# Out:
#               1         2         3         4         6         7         8  \
# ModelID
# ACH-000748  0.0  2.931751  1.300346  0.968795  0.079798  2.580413  0.242330
# ACH-000645  0.0  1.865084  0.886528  0.897159  0.156185  2.279790  0.061815
# ACH-000361  0.0  2.906988  1.973957  0.100008  0.000000  2.699383  0.000000
# ACH-000500  0.0  2.159487  1.752940  0.288381  0.000000  2.658966  0.000000
# ACH-000305  0.0  2.629987  1.629254  0.000000  0.000000  3.175623  0.000000
#
#                    9        11   12  ...   24        25        26   27   28  \
# ModelID                              ...
# ACH-000748  3.798377  4.988098  0.0  ...  0.0  4.071278  1.407413  0.0  0.0
# ACH-000645  3.558936  3.101457  0.0  ...  0.0  2.596276  0.817676  0.0  0.0
# ACH-000361  3.965211  3.971841  0.0  ...  0.0  3.320359  0.911914  0.0  0.0
# ACH-000500  3.791974  3.448829  0.0  ...  0.0  2.962499  0.582971  0.0  0.0
# ACH-000305  4.790333  3.812537  0.0  ...  0.0  3.345766  0.533255  0.0  0.0
#
#                   31        32        33        34        35
# ModelID
# ACH-000748  0.689580  1.444408  0.170970  3.589293  1.664138
# ACH-000645  0.000000  1.385956  0.009952  1.823041  1.082538
# ACH-000361  1.754643  1.337547  0.000000  2.751270  1.274395
# ACH-000500  1.086582  1.592717  0.000000  2.102342  0.958153
# ACH-000305  0.751871  1.744751  0.000000  2.371026  1.104819
#
# [5 rows x 27 columns]

# %%
prism_df_filtered.head()
# Out:
#             BRD-A00077618-236-07-6::2.5::HTS  \
# ModelID
# ACH-000748                          0.040994
# ACH-000645                          0.132239
# ACH-000361                         -0.604188
# ACH-000500                         -0.084264
# ACH-000305                          0.594885
#
#             BRD-A00100033-001-08-9::2.5::HTS  \
# ModelID
# ACH-000748                          0.043226
# ACH-000645                         -0.017053
# ACH-000361                         -0.284897
# ACH-000500                          0.299285
# ACH-000305                         -0.263720
#
#             BRD-A00147595-001-01-5::2.5::HTS  \
# ModelID
# ACH-000748                          0.608362
# ACH-000645                         -0.453666
# ACH-000361                         -0.550330
# ACH-000500                         -0.030174
# ACH-000305                         -0.259307
#
#             BRD-A00218260-001-03-4::2.5::HTS  \
# ModelID
# ACH-000748                          0.621063
# ACH-000645                          0.717919
# ACH-000361                          0.025452
# ACH-000500                          0.455913
# ACH-000305                          0.376236
#
#             BRD-A00376169-001-01-6::2.5::HTS  \
# ModelID
# ACH-000748                          0.433496
# ACH-000645                         -0.933121
# ACH-000361                         -0.279372
# ACH-000500                          0.366639
# ACH-000305                          0.369383
#
#             BRD-A00520476-001-07-4::2.5::HTS  \
# ModelID
# ACH-000748                          0.105630
# ACH-000645                          0.562395
# ACH-000361                          0.391857
# ACH-000500                          0.356831
# ACH-000305                         -0.374505
#
#             BRD-A00546892-001-02-6::2.5::HTS  \
# ModelID
# ACH-000748                          0.640146
# ACH-000645                          0.032053
# ACH-000361                         -0.050825
# ACH-000500                         -0.427765
# ACH-000305                         -0.255021
#
#             BRD-A00578795-001-04-3::2.5::HTS  \
# ModelID
# ACH-000748                          0.174177
# ACH-000645                         -0.860867
# ACH-000361                         -0.587276
# ACH-000500                         -1.202408
# ACH-000305                          0.466388
#
#             BRD-A00758722-001-04-9::2.5::HTS  \
# ModelID
# ACH-000748                         -0.578185
# ACH-000645                         -0.767628
# ACH-000361                         -0.403876
# ACH-000500                         -0.729004
# ACH-000305                         -0.373550
#
#             BRD-A00827783-001-24-6::2.5::HTS  ...  \
# ModelID                                       ...
# ACH-000748                          0.169207  ...
# ACH-000645                         -0.413682  ...
# ACH-000361                          0.351209  ...
# ACH-000500                          0.373132  ...
# ACH-000305                          0.459996  ...
#
#             BRD-K98557884-001-01-6::2.5::MTS004  \
# ModelID
# ACH-000748                            -0.194259
# ACH-000645                             0.500183
# ACH-000361                             0.328679
# ACH-000500                             0.179556
# ACH-000305                             0.562821
#
#             BRD-K99077012-001-01-9::2.332734192::MTS004  \
# ModelID
# ACH-000748                                     0.127125
# ACH-000645                                    -0.111305
# ACH-000361                                    -0.471446
# ACH-000500                                     0.055173
# ACH-000305                                    -0.023984
#
#             BRD-K99199077-001-16-1::2.603211317::MTS004  \
# ModelID
# ACH-000748                                    -0.710559
# ACH-000645                                    -0.143309
# ACH-000361                                    -0.448718
# ACH-000500                                    -0.333961
# ACH-000305                                     0.000466
#
#             BRD-K99431849-001-01-7::2.500018158::MTS004  \
# ModelID
# ACH-000748                                    -0.517990
# ACH-000645                                     0.249487
# ACH-000361                                    -0.026850
# ACH-000500                                    -0.143009
# ACH-000305                                    -0.920437
#
#             BRD-K99447003-335-04-1::2.37737659::MTS004  \
# ModelID
# ACH-000748                                    0.428975
# ACH-000645                                    0.130374
# ACH-000361                                   -0.044571
# ACH-000500                                   -0.406880
# ACH-000305                                    0.135617
#
#             BRD-K99506538-001-03-8::2.5::MTS004  \
# ModelID
# ACH-000748                             0.288549
# ACH-000645                            -0.222888
# ACH-000361                            -0.130468
# ACH-000500                            -0.129199
# ACH-000305                             0.635887
#
#             BRD-K99616396-001-05-1::2.499991421::MTS004  \
# ModelID
# ACH-000748                                    -0.331999
# ACH-000645                                     0.453176
# ACH-000361                                     0.920305
# ACH-000500                                    -0.006238
# ACH-000305                                    -0.594428
#
#             BRD-K99879819-001-02-1::2.5187366::MTS004  \
# ModelID
# ACH-000748                                  -0.129989
# ACH-000645                                  -0.150609
# ACH-000361                                  -1.593728
# ACH-000500                                  -0.592128
# ACH-000305                                  -0.128707
#
#             BRD-K99919177-001-01-3::2.5::MTS004  \
# ModelID
# ACH-000748                            -1.289889
# ACH-000645                            -3.006035
# ACH-000361                            -3.038775
# ACH-000500                            -3.924667
# ACH-000305                            -3.178385
#
#             BRD-M63173034-001-03-6::2.64076472::MTS004
# ModelID
# ACH-000748                                   -0.127920
# ACH-000645                                    0.012878
# ACH-000361                                   -0.620405
# ACH-000500                                   -0.120793
# ACH-000305                                    0.161976
#
# [5 rows x 4686 columns]

# %%
# Create a dataframe to store the Pearson correlation results
correlation_results = []

# Iterate over each latent dimension and drug column
for latent_col in latent_df_filtered.columns:
    for drug_col in prism_df_filtered.columns:
        latent_values = latent_df_filtered[latent_col]
        drug_values = prism_df_filtered[drug_col]

        # Check if either column is constant
        if latent_values.nunique() <= 1 or drug_values.nunique() <= 1:
            corr = np.nan
        else:
            # Drop missing values for both columns
            valid_data = pd.concat([latent_values, drug_values], axis=1).dropna()
            latent_values_valid = valid_data[latent_col]
            drug_values_valid = valid_data[drug_col]

            if len(latent_values_valid) > 1 and len(drug_values_valid) > 1:
                # Calculate Pearson correlation
                corr, _ = pearsonr(latent_values_valid, drug_values_valid)
            else:
                corr = np.nan
                print("nan")
        
        # Store the result
        correlation_results.append({
            'latent_dimension': latent_col,
            'drug': drug_col,
            'correlation': corr
        })

# Convert the results to a dataframe for easier analysis
correlation_df = pd.DataFrame(correlation_results)

# Display the correlation dataframe
correlation_df.sort_values(by='correlation', key=abs, ascending=False).head(50)
# Out:
# /tmp/ipykernel_9168/2901921280.py:21: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, _ = pearsonr(latent_values_valid, drug_values_valid)
#        latent_dimension                                         drug  \
# 111864               32             BRD-K98572433-001-02-9::2.5::HTS
# 112240               32          BRD-K50010139-001-02-3::2.5::MTS004
# 110728               32             BRD-K64052750-001-17-5::2.5::HTS
# 109458               32             BRD-K26603252-003-04-9::2.5::HTS
# 110934               32             BRD-K70301465-001-02-6::2.5::HTS
# 111035               32             BRD-K73309154-003-02-8::2.5::HTS
# 111126               32             BRD-K76239644-001-01-8::2.5::HTS
# 110108               32             BRD-K46386702-001-02-1::2.5::HTS
# 110046               32             BRD-K44844162-001-01-6::2.5::HTS
# 109346               32             BRD-K23190681-001-01-1::2.5::HTS
# 109912               32             BRD-K40718343-001-02-6::2.5::HTS
# 108793               32             BRD-K07106112-003-03-8::2.5::HTS
# 26520                 7             BRD-K68395654-001-03-1::2.5::HTS
# 64008                19             BRD-K68395654-001-03-1::2.5::HTS
# 110864               32             BRD-K68336408-001-10-9::2.5::HTS
# 35892                 9             BRD-K68395654-001-03-1::2.5::HTS
# 109161               32             BRD-K17702546-001-03-2::2.5::HTS
# 26248                 7             BRD-K60443845-001-08-6::2.5::HTS
# 111460               32             BRD-K85606544-001-09-1::2.5::HTS
# 63736                19             BRD-K60443845-001-08-6::2.5::HTS
# 35620                 9             BRD-K60443845-001-08-6::2.5::HTS
# 54364                15             BRD-K60443845-001-08-6::2.5::HTS
# 7776                  2             BRD-K68395654-001-03-1::2.5::HTS
# 54636                15             BRD-K68395654-001-03-1::2.5::HTS
# 109473               32             BRD-K26838195-075-04-9::2.5::HTS
# 109981               32             BRD-K42805893-001-04-9::2.5::HTS
# 111265               32             BRD-K79930101-300-03-7::2.5::HTS
# 7504                  2             BRD-K60443845-001-08-6::2.5::HTS
# 68768                20             BRD-K70463136-001-01-5::2.5::HTS
# 112043               32  BRD-K03765900-001-01-9::2.499986292::MTS004
# 26594                 7             BRD-K70463136-001-01-5::2.5::HTS
# 109239               32             BRD-K19687926-379-07-4::2.5::HTS
# 87438                25             BRD-K68395654-001-03-1::2.5::HTS
# 77179                23             BRD-K42805893-001-04-9::2.5::HTS
# 87166                25             BRD-K60443845-001-08-6::2.5::HTS
# 58435                16             BRD-K42805893-001-04-9::2.5::HTS
# 16261                 4             BRD-K42805893-001-04-9::2.5::HTS
# 64082                19             BRD-K70463136-001-01-5::2.5::HTS
# 67807                20             BRD-K42805893-001-04-9::2.5::HTS
# 110256               32             BRD-K50168500-001-07-9::2.5::HTS
# 4703                  2             BRD-A01643550-001-04-9::2.5::HTS
# 60935                19             BRD-A01643550-001-04-9::2.5::HTS
# 84365                25             BRD-A01643550-001-04-9::2.5::HTS
# 106545               31             BRD-K78960041-001-03-2::2.5::HTS
# 106182               31             BRD-K68395654-001-03-1::2.5::HTS
# 51563                15             BRD-A01643550-001-04-9::2.5::HTS
# 35966                 9             BRD-K70463136-001-01-5::2.5::HTS
# 109319               32             BRD-K22025381-003-01-9::2.5::HTS
# 110212               32             BRD-K49294207-300-03-8::2.5::HTS
# 110957               32             BRD-K70914287-300-02-8::2.5::HTS
#
#         correlation
# 111864    -0.424845
# 112240    -0.412080
# 110728    -0.396887
# 109458    -0.393700
# 110934    -0.393304
# 111035    -0.392537
# 111126    -0.384671
# 110108    -0.373803
# 110046    -0.373797
# 109346    -0.371871
# 109912    -0.371143
# 108793    -0.370902
# 26520     -0.363622
# 64008     -0.360149
# 110864    -0.358600
# 35892     -0.357967
# 109161    -0.357655
# 26248     -0.352771
# 111460    -0.351015
# 63736     -0.350837
# 35620     -0.350197
# 54364     -0.349040
# 7776      -0.348887
# 54636     -0.346778
# 109473    -0.343215
# 109981    -0.342892
# 111265    -0.342379
# 7504      -0.340351
# 68768      0.338609
# 112043    -0.334955
# 26594     -0.333898
# 109239    -0.333409
# 87438     -0.332580
# 77179      0.329151
# 87166     -0.327515
# 58435      0.327336
# 16261      0.326581
# 64082     -0.326576
# 67807      0.324488
# 110256    -0.323078
# 4703      -0.321354
# 60935     -0.319917
# 84365     -0.317553
# 106545    -0.316206
# 106182    -0.315373
# 51563     -0.313851
# 35966     -0.312266
# 109319    -0.311781
# 110212    -0.310289
# 110957    -0.309776

# %%
#Sort pathways by NES score (ascending order)
pathway_df.sort_values(by='nes', ascending=True)

ranked_gsea = pathway_df.sort_values(by='nes', key=abs, ascending=False)

#Group by 'z_dim' and aggregate 'Term' into a list of associated pathways
grouped_pathway_df = ranked_gsea.groupby('z_dim').apply(lambda x: x.nlargest(10, 'nes')['Term'].tolist()).reset_index(drop=False)

# remove z_
grouped_pathway_df['z_dim'] = grouped_pathway_df['z_dim'].str.replace('z_', '', regex=False)

grouped_pathway_df.columns = ['latent dimension', 'Associated Pathways']

grouped_pathway_df.head()
# Out:
# /tmp/ipykernel_9168/1535159008.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_pathway_df = ranked_gsea.groupby('z_dim').apply(lambda x: x.nlargest(10, 'nes')['Term'].tolist()).reset_index(drop=False)
#   latent dimension                                Associated Pathways
# 0                1  [rRNA Processing R-HSA-72312, rRNA Processing ...
# 1               10  [Formation Of ATP By Chemiosmotic Coupling R-H...
# 2               11  [rRNA Processing In Nucleus And Cytosol R-HSA-...
# 3               12  [S Phase R-HSA-69242, DNA Replication R-HSA-69...
# 4               13  [Leishmania Infection R-HSA-9658195, Fcgamma R...

# %%
# Assuming 'drug_column_name' is the column in prism_trt_df that matches the 'drug' column in correlation_df
prism_trt_df_filtered = prism_trt_df[['column_name', 'name', 'moa', 'target']]

# Merge correlation_df with prism_trt_df based on the 'drug' column in correlation_df and the matching column in prism_trt_df
correlation_df_merged1 = pd.merge(correlation_df, prism_trt_df_filtered, how='left', left_on='drug', right_on='column_name')

# Drop the redundant drug_column_name column after the merge if needed
correlation_df_merged1 = correlation_df_merged1.drop(columns=['column_name'])

# Merge correlation_df with prism_trt_df based on the 'drug' column in correlation_df and the matching column in prism_trt_df
correlation_df_merged = pd.merge(correlation_df_merged1, grouped_pathway_df, how='left', left_on='latent_dimension', right_on='latent dimension')

# Drop the redundant drug_column_name column after the merge if needed
correlation_df_merged = correlation_df_merged.drop(columns=['latent dimension'])

significant_corr_df = correlation_df_merged[
    (correlation_df_merged['correlation'].abs() > 0.1)
]
# saving results as single output file
correlation_dir = pathlib.Path("./results/drug_correlation.csv")
significant_corr_df.to_csv(correlation_dir)

# Display the updated dataframe with the new columns
correlation_df_merged.sort_values(by='correlation', key=abs, ascending=False).head(50)
# Out:
#        latent_dimension                                         drug  \
# 111864               32             BRD-K98572433-001-02-9::2.5::HTS
# 112240               32          BRD-K50010139-001-02-3::2.5::MTS004
# 110728               32             BRD-K64052750-001-17-5::2.5::HTS
# 109458               32             BRD-K26603252-003-04-9::2.5::HTS
# 110934               32             BRD-K70301465-001-02-6::2.5::HTS
# 111035               32             BRD-K73309154-003-02-8::2.5::HTS
# 111126               32             BRD-K76239644-001-01-8::2.5::HTS
# 110108               32             BRD-K46386702-001-02-1::2.5::HTS
# 110046               32             BRD-K44844162-001-01-6::2.5::HTS
# 109346               32             BRD-K23190681-001-01-1::2.5::HTS
# 109912               32             BRD-K40718343-001-02-6::2.5::HTS
# 108793               32             BRD-K07106112-003-03-8::2.5::HTS
# 26520                 7             BRD-K68395654-001-03-1::2.5::HTS
# 64008                19             BRD-K68395654-001-03-1::2.5::HTS
# 110864               32             BRD-K68336408-001-10-9::2.5::HTS
# 35892                 9             BRD-K68395654-001-03-1::2.5::HTS
# 109161               32             BRD-K17702546-001-03-2::2.5::HTS
# 26248                 7             BRD-K60443845-001-08-6::2.5::HTS
# 111460               32             BRD-K85606544-001-09-1::2.5::HTS
# 63736                19             BRD-K60443845-001-08-6::2.5::HTS
# 35620                 9             BRD-K60443845-001-08-6::2.5::HTS
# 54364                15             BRD-K60443845-001-08-6::2.5::HTS
# 7776                  2             BRD-K68395654-001-03-1::2.5::HTS
# 54636                15             BRD-K68395654-001-03-1::2.5::HTS
# 109473               32             BRD-K26838195-075-04-9::2.5::HTS
# 109981               32             BRD-K42805893-001-04-9::2.5::HTS
# 111265               32             BRD-K79930101-300-03-7::2.5::HTS
# 7504                  2             BRD-K60443845-001-08-6::2.5::HTS
# 68768                20             BRD-K70463136-001-01-5::2.5::HTS
# 112043               32  BRD-K03765900-001-01-9::2.499986292::MTS004
# 26594                 7             BRD-K70463136-001-01-5::2.5::HTS
# 109239               32             BRD-K19687926-379-07-4::2.5::HTS
# 87438                25             BRD-K68395654-001-03-1::2.5::HTS
# 77179                23             BRD-K42805893-001-04-9::2.5::HTS
# 87166                25             BRD-K60443845-001-08-6::2.5::HTS
# 58435                16             BRD-K42805893-001-04-9::2.5::HTS
# 16261                 4             BRD-K42805893-001-04-9::2.5::HTS
# 64082                19             BRD-K70463136-001-01-5::2.5::HTS
# 67807                20             BRD-K42805893-001-04-9::2.5::HTS
# 110256               32             BRD-K50168500-001-07-9::2.5::HTS
# 4703                  2             BRD-A01643550-001-04-9::2.5::HTS
# 60935                19             BRD-A01643550-001-04-9::2.5::HTS
# 84365                25             BRD-A01643550-001-04-9::2.5::HTS
# 106545               31             BRD-K78960041-001-03-2::2.5::HTS
# 106182               31             BRD-K68395654-001-03-1::2.5::HTS
# 51563                15             BRD-A01643550-001-04-9::2.5::HTS
# 35966                 9             BRD-K70463136-001-01-5::2.5::HTS
# 109319               32             BRD-K22025381-003-01-9::2.5::HTS
# 110212               32             BRD-K49294207-300-03-8::2.5::HTS
# 110957               32             BRD-K70914287-300-02-8::2.5::HTS
#
#         correlation                  name  \
# 111864    -0.424845               AZD8931
# 112240    -0.412080            poziotinib
# 110728    -0.396887             gefitinib
# 109458    -0.393700             PD-153035
# 110934    -0.393304             ibrutinib
# 111035    -0.392537               OSI-420
# 111126    -0.384671            BMS-690514
# 110108    -0.373803           ARRY-334543
# 110046    -0.373797             taselisib
# 109346    -0.371871                AV-412
# 109912    -0.371143                AEE788
# 108793    -0.370902            BMS-599626
# 26520     -0.363622               EVP4593
# 64008     -0.360149               EVP4593
# 110864    -0.358600    tyrphostin-AG-1478
# 35892     -0.357967               EVP4593
# 109161    -0.357655             PD-168393
# 26248     -0.352771         chlormidazole
# 111460    -0.351015             neratinib
# 63736     -0.350837         chlormidazole
# 35620     -0.350197         chlormidazole
# 54364     -0.349040         chlormidazole
# 7776      -0.348887               EVP4593
# 54636     -0.346778               EVP4593
# 109473    -0.343215              AST-1306
# 109981    -0.342892           osimertinib
# 111265    -0.342379             GW-583340
# 7504      -0.340351         chlormidazole
# 68768      0.338609           BAY-87-2243
# 112043    -0.334955                XL-647
# 26594     -0.333898           BAY-87-2243
# 109239    -0.333409             lapatinib
# 87438     -0.332580               EVP4593
# 77179      0.329151           osimertinib
# 87166     -0.327515         chlormidazole
# 58435      0.327336           osimertinib
# 16261      0.326581           osimertinib
# 64082     -0.326576           BAY-87-2243
# 67807      0.324488           osimertinib
# 110256    -0.323078            canertinib
# 4703      -0.321354  prednisolone-acetate
# 60935     -0.319917  prednisolone-acetate
# 84365     -0.317553  prednisolone-acetate
# 106545    -0.316206           oxaliplatin
# 106182    -0.315373               EVP4593
# 51563     -0.313851  prednisolone-acetate
# 35966     -0.312266           BAY-87-2243
# 109319    -0.311781              U-18666A
# 110212    -0.310289             BIBU-1361
# 110957    -0.309776             BIBX-1382
#
#                                                       moa  \
# 111864                                     EGFR inhibitor
# 112240                                     EGFR inhibitor
# 110728                                     EGFR inhibitor
# 109458                                     EGFR inhibitor
# 110934           Bruton's tyrosine kinase (BTK) inhibitor
# 111035                                     EGFR inhibitor
# 111126                    EGFR inhibitor, VEGFR inhibitor
# 110108                                     EGFR inhibitor
# 110046                                     PI3K inhibitor
# 109346                  protein tyrosine kinase inhibitor
# 109912                    EGFR inhibitor, VEGFR inhibitor
# 108793  EGFR inhibitor, protein tyrosine kinase inhibitor
# 26520                              NFkB pathway inhibitor
# 64008                              NFkB pathway inhibitor
# 110864                                     EGFR inhibitor
# 35892                              NFkB pathway inhibitor
# 109161                                     EGFR inhibitor
# 26248             fungal lanosterol demethylase inhibitor
# 111460                                     EGFR inhibitor
# 63736             fungal lanosterol demethylase inhibitor
# 35620             fungal lanosterol demethylase inhibitor
# 54364             fungal lanosterol demethylase inhibitor
# 7776                               NFkB pathway inhibitor
# 54636                              NFkB pathway inhibitor
# 109473                                     EGFR inhibitor
# 109981                                     EGFR inhibitor
# 111265                                     EGFR inhibitor
# 7504              fungal lanosterol demethylase inhibitor
# 68768                  hypoxia inducible factor inhibitor
# 112043                    EGFR inhibitor, VEGFR inhibitor
# 26594                  hypoxia inducible factor inhibitor
# 109239                                     EGFR inhibitor
# 87438                              NFkB pathway inhibitor
# 77179                                      EGFR inhibitor
# 87166             fungal lanosterol demethylase inhibitor
# 58435                                      EGFR inhibitor
# 16261                                      EGFR inhibitor
# 64082                  hypoxia inducible factor inhibitor
# 67807                                      EGFR inhibitor
# 110256                                     EGFR inhibitor
# 4703                      glucocorticoid receptor agonist
# 60935                     glucocorticoid receptor agonist
# 84365                     glucocorticoid receptor agonist
# 106545                                      DNA inhibitor
# 106182                             NFkB pathway inhibitor
# 51563                     glucocorticoid receptor agonist
# 35966                  hypoxia inducible factor inhibitor
# 109319                    oxidosqualene cyclase inhibitor
# 110212                                     EGFR inhibitor
# 110957                                     EGFR inhibitor
#
#                                        target  \
# 111864                     EGFR, ERBB2, ERBB3
# 112240                     EGFR, ERBB2, ERBB4
# 110728                                   EGFR
# 109458                              EGFR, KDR
# 110934                          BLK, BMX, BTK
# 111035                                   EGFR
# 111126                 EGFR, ERBB2, FLT3, KDR
# 110108                                  ERBB2
# 110046                                 PIK3CA
# 109346                            EGFR, ERBB2
# 109912  EGFR, ERBB2, ERBB4, FGFR2, FGFR3, KDR
# 108793                     EGFR, ERBB2, ERBB4
# 26520                                     NaN
# 64008                                     NaN
# 110864                           EGFR, MAPK14
# 35892                                     NaN
# 109161                       EGFR, ERBB2, SRC
# 26248                                     NaN
# 111460                       EGFR, ERBB2, KDR
# 63736                                     NaN
# 35620                                     NaN
# 54364                                     NaN
# 7776                                      NaN
# 54636                                     NaN
# 109473                            EGFR, ERBB2
# 109981                                   EGFR
# 111265                            EGFR, ERBB2
# 7504                                      NaN
# 68768                                   HIF1A
# 112043          EGFR, EPHB4, ERBB2, FLT4, KDR
# 26594                                   HIF1A
# 109239                            EGFR, ERBB2
# 87438                                     NaN
# 77179                                    EGFR
# 87166                                     NaN
# 58435                                    EGFR
# 16261                                    EGFR
# 64082                                   HIF1A
# 67807                                    EGFR
# 110256               AKT1, EGFR, ERBB2, ERBB4
# 4703                                    NR3C1
# 60935                                   NR3C1
# 84365                                   NR3C1
# 106545                                    NaN
# 106182                                    NaN
# 51563                                   NR3C1
# 35966                                   HIF1A
# 109319                                    NaN
# 110212                                   EGFR
# 110957                            EGFR, ERBB2
#
#                                       Associated Pathways
# 111864  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 112240  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 110728  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 109458  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 110934  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 111035  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 111126  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 110108  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 110046  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 109346  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 109912  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 108793  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 26520   [Citric Acid (TCA) Cycle And Respiratory Elect...
# 64008   [rRNA Processing R-HSA-72312, rRNA Processing ...
# 110864  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 35892   [Citric Acid (TCA) Cycle And Respiratory Elect...
# 109161  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 26248   [Citric Acid (TCA) Cycle And Respiratory Elect...
# 111460  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 63736   [rRNA Processing R-HSA-72312, rRNA Processing ...
# 35620   [Citric Acid (TCA) Cycle And Respiratory Elect...
# 54364   [rRNA Processing R-HSA-72312, rRNA Processing ...
# 7776    [Citric Acid (TCA) Cycle And Respiratory Elect...
# 54636   [rRNA Processing R-HSA-72312, rRNA Processing ...
# 109473  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 109981  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 111265  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 7504    [Citric Acid (TCA) Cycle And Respiratory Elect...
# 68768   [APC/C-mediated Degradation Of Cell Cycle Prot...
# 112043  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 26594   [Citric Acid (TCA) Cycle And Respiratory Elect...
# 109239  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 87438   [Metabolism Of Nucleotides R-HSA-15869, Metabo...
# 77179   [Citric Acid (TCA) Cycle And Respiratory Elect...
# 87166   [Metabolism Of Nucleotides R-HSA-15869, Metabo...
# 58435   [APC/C:Cdh1 Mediated Degradation Of Cdc20 And ...
# 16261   [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 64082   [rRNA Processing R-HSA-72312, rRNA Processing ...
# 67807   [APC/C-mediated Degradation Of Cell Cycle Prot...
# 110256  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 4703    [Citric Acid (TCA) Cycle And Respiratory Elect...
# 60935   [rRNA Processing R-HSA-72312, rRNA Processing ...
# 84365   [Metabolism Of Nucleotides R-HSA-15869, Metabo...
# 106545  [rRNA Processing R-HSA-72312, tRNA Modificatio...
# 106182  [rRNA Processing R-HSA-72312, tRNA Modificatio...
# 51563   [rRNA Processing R-HSA-72312, rRNA Processing ...
# 35966   [Citric Acid (TCA) Cycle And Respiratory Elect...
# 109319  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 110212  [Cilium Assembly R-HSA-5617833, Regulation Of ...
# 110957  [Cilium Assembly R-HSA-5617833, Regulation Of ...
