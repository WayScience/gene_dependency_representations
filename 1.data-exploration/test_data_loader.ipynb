# %%
import sys
import pathlib
import pandas as pd 
import numpy as np

sys.path.insert(0, "../0.data-download/scripts")
from data_loader import load_data

data_directory = "../0.data-download/data/"
dfs = load_data(data_directory, adult_or_pediatric = "all")

# %%
dfs[0]
# Out:
#        DepMap_ID cell_line_name stripped_cell_line_name  \
# 0     ACH-000076           NCO2                    NCO2
# 1     ACH-000077             MJ                      MJ
# 2     ACH-000093     Panc 05.04                PANC0504
# 3     ACH-000172          TM-87                    TM87
# 4     ACH-000216      JH-EsoAd1                JHESOAD1
# ...          ...            ...                     ...
# 1081  ACH-002296         PCI-38                   PCI38
# 1082  ACH-002297         PCI-4B                   PCI4B
# 1083  ACH-002298         PCI-6A                   PCI6A
# 1084  ACH-002304        SK-MG-1                   SKMG1
# 1085  ACH-002305          SKN-3                    SKN3
#
#                                     CCLE_Name alias   COSMICID     sex  \
# 0     NCO2_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE   NaN        NaN  Female
# 1       MJ_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE   NaN        NaN    Male
# 2                           PANC0504_PANCREAS   NaN        NaN  Female
# 3                            TM87_SOFT_TISSUE  TM87        NaN    Male
# 4                         JHESOAD1_OESOPHAGUS   NaN        NaN    Male
# ...                                       ...   ...        ...     ...
# 1081          PCI38_UPPER_AERODIGESTIVE_TRACT   NaN  1240205.0    Male
# 1082          PCI4B_UPPER_AERODIGESTIVE_TRACT   NaN  1298531.0    Male
# 1083          PCI6A_UPPER_AERODIGESTIVE_TRACT   NaN  1240206.0    Male
# 1084             SKMG1_CENTRAL_NERVOUS_SYSTEM   NaN   909729.0     NaN
# 1085           SKN3_UPPER_AERODIGESTIVE_TRACT   NaN  1299059.0     NaN
#
#             source       RRID  WTSI_Master_Cell_ID  ...  \
# 0            HSRRB  CVCL_3043                  NaN  ...
# 1             ATCC  CVCL_1414                  NaN  ...
# 2             ATCC  CVCL_1637                  NaN  ...
# 3     Academic lab  CVCL_8001                  NaN  ...
# 4     Academic lab  CVCL_8098                  NaN  ...
# ...            ...        ...                  ...  ...
# 1081        Sanger  CVCL_M471                334.0  ...
# 1082        Sanger  CVCL_C171               1068.0  ...
# 1083        Sanger  CVCL_C173               1218.0  ...
# 1084        Sanger  CVCL_1698                578.0  ...
# 1085        Sanger  CVCL_3168               1910.0  ...
#
#      default_growth_pattern model_manipulation model_manipulation_details  \
# 0                       NaN                NaN                        NaN
# 1            2D: suspension                NaN                        NaN
# 2              2D: adherent                NaN                        NaN
# 3                       NaN                NaN                        NaN
# 4                       NaN                NaN                        NaN
# ...                     ...                ...                        ...
# 1081                    NaN                NaN                        NaN
# 1082                    NaN                NaN                        NaN
# 1083                    NaN                NaN                        NaN
# 1084                    NaN                NaN                        NaN
# 1085                    NaN                NaN                        NaN
#
#      patient_id parent_depmap_id  \
# 0     PT-Ugji7b              NaN
# 1     PT-brIUSU              NaN
# 2     PT-aJgS51              NaN
# 3     PT-o2d0Va              NaN
# 4     PT-Y4syw7              NaN
# ...         ...              ...
# 1081  PT-oqands              NaN
# 1082  PT-kYHcXz              NaN
# 1083  PT-mnzvO8              NaN
# 1084  PT-bxaITj       ACH-002596
# 1085  PT-ErYkxf              NaN
#
#                              Cellosaurus_NCIt_disease Cellosaurus_NCIt_id  \
# 0     Chronic myelogenous leukemia, BCR-ABL1 positive               C3174
# 1       Primary cutaneous T-cell non-Hodgkin lymphoma               C3467
# 2                    Pancreatic ductal adenocarcinoma               C9120
# 3                           Extrarenal rhabdoid tumor               C6586
# 4                              Barrett adenocarcinoma               C7027
# ...                                               ...                 ...
# 1081                   Tongue squamous cell carcinoma               C4648
# 1082                Laryngeal squamous cell carcinoma               C4044
# 1083                Tonsillar squamous cell carcinoma               C8183
# 1084                                      Astrocytoma              C60781
# 1085              Oral cavity squamous cell carcinoma               C4833
#
#                                      Cellosaurus_issues age_categories  \
# 0                                                   NaN          Adult
# 1                                                   NaN          Adult
# 2                                                   NaN          Adult
# 3                                                   NaN      Pediatric
# 4                                                   NaN          Adult
# ...                                                 ...            ...
# 1081                                                NaN          Adult
# 1082                                                NaN          Adult
# 1083                                                NaN          Adult
# 1084  Contaminated. Shown to be a Marcus derivative ...        Missing
# 1085                                                NaN        Missing
#
#      age_distribution
# 0                35.0
# 1                50.0
# 2                77.0
# 3                 1.0
# 4                66.0
# ...               ...
# 1081             56.0
# 1082             51.0
# 1083             81.0
# 1084              NaN
# 1085              NaN
#
# [1086 rows x 31 columns]

# %%
dfs[1]
# Out:
#        DepMap_ID  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 0     ACH-000001  0.094568      0.012519  0.027460        0.025962
# 1     ACH-000004  0.012676      0.049011  0.075933        0.033215
# 2     ACH-000005  0.053957      0.027968  0.010139        0.005448
# 3     ACH-000007  0.026704      0.083588  0.008853        0.011299
# 4     ACH-000009  0.059383      0.051826  0.015370        0.011721
# ...          ...       ...           ...       ...             ...
# 1081  ACH-002834  0.012720      0.083840  0.013308        0.013315
# 1082  ACH-002847  0.058547      0.079576  0.036707        0.030234
# 1083  ACH-002874  0.169875      0.017430  0.017965        0.008615
# 1084  ACH-002875  0.035519      0.099789  0.071748        0.048479
# 1085  ACH-002926  0.022010      0.023496  0.012432        0.007420
#
#       A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# 0             0.073412        0.027340       0.020199     0.284733
# 1             0.013176        0.097497       0.005015     0.153166
# 2             0.018599        0.081636       0.005457     0.159904
# 3             0.027288        0.028349       0.032573     0.166503
# 4             0.030062        0.078373       0.042128     0.184783
# ...                ...             ...            ...          ...
# 1081          0.107286        0.079063       0.013340     0.717478
# 1082          0.069976        0.032828       0.012784     0.476383
# 1083          0.117915        0.075693       0.087961     0.144152
# 1084          0.245413        0.154663       0.045155     0.324723
# 1085          0.018041        0.035598       0.057725     0.272390
#
#       AACS (65985)  ...  ZWILCH (55055)  ZWINT (11130)  ZXDA (7789)  \
# 0         0.022084  ...        0.037449       0.080585     0.034309
# 1         0.007358  ...        0.038768       0.230569     0.007125
# 2         0.050884  ...        0.017479       0.274568     0.054525
# 3         0.047045  ...        0.196233       0.615338     0.011212
# 4         0.032335  ...        0.152385       0.405712     0.029011
# ...            ...  ...             ...            ...          ...
# 1081      0.040061  ...        0.027170       0.636352     0.022403
# 1082      0.096910  ...        0.476423       0.967625     0.014249
# 1083      0.140377  ...        0.710398       0.747477     0.045149
# 1084      0.089083  ...        0.329219       0.168367     0.055878
# 1085      0.034980  ...        0.669718       0.939699     0.013556
#
#       ZXDB (158586)  ZXDC (79364)  ZYG11A (440590)  ZYG11B (79699)  \
# 0          0.007142      0.004241         0.082956        0.012000
# 1          0.021209      0.011203         0.060266        0.128375
# 2          0.033396      0.033416         0.034712        0.092832
# 3          0.002200      0.005432         0.035241        0.138445
# 4          0.002816      0.056461         0.189550        0.328064
# ...             ...           ...              ...             ...
# 1081       0.052849      0.029567         0.029711        0.024132
# 1082       0.018715      0.010776         0.072452        0.131375
# 1083       0.044243      0.017923         0.077515        0.094231
# 1084       0.039710      0.017571         0.101216        0.087739
# 1085       0.001120      0.057491         0.028312        0.104833
#
#       ZYX (7791)  ZZEF1 (23140)  ZZZ3 (26009)
# 0       0.003592       0.012679      0.324623
# 1       0.005911       0.004645      0.042530
# 2       0.012482       0.020843      0.050412
# 3       0.103161       0.146222      0.274833
# 4       0.035161       0.058402      0.269194
# ...          ...            ...           ...
# 1081    0.174946       0.091510      0.421153
# 1082    0.115486       0.094022      0.438092
# 1083    0.166188       0.058117      0.302708
# 1084    0.050947       0.182081      0.349872
# 1085    0.008261       0.035919      0.404214
#
# [1086 rows x 17387 columns]
